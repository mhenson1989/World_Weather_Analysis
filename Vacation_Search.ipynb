# %% [markdown]
# ## Deliverable 2. Create a Customer Travel Destinations Map.

# %%
pip install gmaps
# Out:
# Collecting gmaps
#   Downloading gmaps-0.9.0.tar.gz (1.1 MB)
# Requirement already satisfied: ipython>=5.3.0 in c:\users\admin\anaconda3\envs\pythondata\lib\site-packages (from gmaps) (7.31.1)
# Requirement already satisfied: ipywidgets>=7.0.0 in c:\users\admin\anaconda3\envs\pythondata\lib\site-packages (from gmaps) (7.6.5)
# Requirement already satisfied: traitlets>=4.3.0 in c:\users\admin\anaconda3\envs\pythondata\lib\site-packages (from gmaps) (5.1.1)
# Collecting geojson>=2.0.0
#   Downloading geojson-2.5.0-py2.py3-none-any.whl (14 kB)
# Requirement already satisfied: six in c:\users\admin\anaconda3\envs\pythondata\lib\site-packages (from gmaps) (1.16.0)
# Requirement already satisfied: decorator in c:\users\admin\anaconda3\envs\pythondata\lib\site-packages (from ipython>=5.3.0->gmaps) (5.1.1)
# Requirement already satisfied: pygments in c:\users\admin\anaconda3\envs\pythondata\lib\site-packages (from ipython>=5.3.0->gmaps) (2.11.2)
# Requirement already satisfied: backcall in c:\users\admin\anaconda3\envs\pythondata\lib\site-packages (from ipython>=5.3.0->gmaps) (0.2.0)
# Requirement already satisfied: colorama in c:\users\admin\anaconda3\envs\pythondata\lib\site-packages (from ipython>=5.3.0->gmaps) (0.4.4)
# Requirement already satisfied: pickleshare in c:\users\admin\anaconda3\envs\pythondata\lib\site-packages (from ipython>=5.3.0->gmaps) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\admin\anaconda3\envs\pythondata\lib\site-packages (from ipython>=5.3.0->gmaps) (3.0.20)
# Requirement already satisfied: matplotlib-inline in c:\users\admin\anaconda3\envs\pythondata\lib\site-packages (from ipython>=5.3.0->gmaps) (0.1.2)
# Requirement already satisfied: jedi>=0.16 in c:\users\admin\anaconda3\envs\pythondata\lib\site-packages (from ipython>=5.3.0->gmaps) (0.18.1)
# Requirement already satisfied: setuptools>=18.5 in c:\users\admin\anaconda3\envs\pythondata\lib\site-packages (from ipython>=5.3.0->gmaps) (61.2.0)
# Requirement already satisfied: nbformat>=4.2.0 in c:\users\admin\anaconda3\envs\pythondata\lib\site-packages (from ipywidgets>=7.0.0->gmaps) (5.3.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in c:\users\admin\anaconda3\envs\pythondata\lib\site-packages (from ipywidgets>=7.0.0->gmaps) (1.0.0)
# Requirement already satisfied: ipykernel>=4.5.1 in c:\users\admin\anaconda3\envs\pythondata\lib\site-packages (from ipywidgets>=7.0.0->gmaps) (6.9.1)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in c:\users\admin\anaconda3\envs\pythondata\lib\site-packages (from ipywidgets>=7.0.0->gmaps) (3.5.2)
# Requirement already satisfied: ipython-genutils~=0.2.0 in c:\users\admin\anaconda3\envs\pythondata\lib\site-packages (from ipywidgets>=7.0.0->gmaps) (0.2.0)
# Requirement already satisfied: nest-asyncio in c:\users\admin\anaconda3\envs\pythondata\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (1.5.5)
# Requirement already satisfied: tornado<7.0,>=4.2 in c:\users\admin\anaconda3\envs\pythondata\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (6.1)
# Requirement already satisfied: jupyter-client<8.0 in c:\users\admin\anaconda3\envs\pythondata\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (6.1.12)
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in c:\users\admin\anaconda3\envs\pythondata\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (1.5.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\admin\anaconda3\envs\pythondata\lib\site-packages (from jedi>=0.16->ipython>=5.3.0->gmaps) (0.8.3)
# Requirement already satisfied: python-dateutil>=2.1 in c:\users\admin\anaconda3\envs\pythondata\lib\site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (2.8.2)
# Requirement already satisfied: jupyter-core>=4.6.0 in c:\users\admin\anaconda3\envs\pythondata\lib\site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (4.9.2)
# Requirement already satisfied: pyzmq>=13 in c:\users\admin\anaconda3\envs\pythondata\lib\site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (22.3.0)
# Requirement already satisfied: pywin32>=1.0 in c:\users\admin\anaconda3\envs\pythondata\lib\site-packages (from jupyter-core>=4.6.0->jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets>=7.0.0->gmaps) (302)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\admin\anaconda3\envs\pythondata\lib\site-packages (from nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (4.4.0)
# Requirement already satisfied: fastjsonschema in c:\users\admin\anaconda3\envs\pythondata\lib\site-packages (from nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (2.15.1)
# Requirement already satisfied: importlib-metadata in c:\users\admin\anaconda3\envs\pythondata\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (4.11.3)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\admin\anaconda3\envs\pythondata\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (0.18.0)
# Requirement already satisfied: importlib-resources>=1.4.0 in c:\users\admin\anaconda3\envs\pythondata\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (5.2.0)
# Requirement already satisfied: typing-extensions in c:\users\admin\anaconda3\envs\pythondata\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (4.1.1)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\admin\anaconda3\envs\pythondata\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (21.4.0)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\admin\anaconda3\envs\pythondata\lib\site-packages (from importlib-resources>=1.4.0->jsonschema>=2.6->nbformat>=4.2.0->ipywidgets>=7.0.0->gmaps) (3.7.0)
# Requirement already satisfied: wcwidth in c:\users\admin\anaconda3\envs\pythondata\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=5.3.0->gmaps) (0.2.5)
# Requirement already satisfied: notebook>=4.4.1 in c:\users\admin\anaconda3\envs\pythondata\lib\site-packages (from widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (6.4.8)
# Requirement already satisfied: nbconvert in c:\users\admin\anaconda3\envs\pythondata\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (6.4.4)Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: terminado>=0.8.3 in c:\users\admin\anaconda3\envs\pythondata\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.13.1)
# Requirement already satisfied: prometheus-client in c:\users\admin\anaconda3\envs\pythondata\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.13.1)
# Requirement already satisfied: jinja2 in c:\users\admin\anaconda3\envs\pythondata\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (2.11.3)
# Requirement already satisfied: argon2-cffi in c:\users\admin\anaconda3\envs\pythondata\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (21.3.0)
# Requirement already satisfied: Send2Trash>=1.8.0 in c:\users\admin\anaconda3\envs\pythondata\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (1.8.0)
# Requirement already satisfied: pywinpty>=1.1.0 in c:\users\admin\anaconda3\envs\pythondata\lib\site-packages (from terminado>=0.8.3->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (2.0.2)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\admin\anaconda3\envs\pythondata\lib\site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (21.2.0)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\admin\anaconda3\envs\pythondata\lib\site-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (1.15.0)
# Requirement already satisfied: pycparser in c:\users\admin\anaconda3\envs\pythondata\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (2.21)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\admin\anaconda3\envs\pythondata\lib\site-packages (from jinja2->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (2.0.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\admin\anaconda3\envs\pythondata\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (1.5.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\admin\anaconda3\envs\pythondata\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.8.4)
# Requirement already satisfied: entrypoints>=0.2.2 in c:\users\admin\anaconda3\envs\pythondata\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.4)
# Requirement already satisfied: beautifulsoup4 in c:\users\admin\anaconda3\envs\pythondata\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (4.11.1)
# Requirement already satisfied: testpath in c:\users\admin\anaconda3\envs\pythondata\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.5.0)
# Requirement already satisfied: bleach in c:\users\admin\anaconda3\envs\pythondata\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (4.1.0)
# Requirement already satisfied: defusedxml in c:\users\admin\anaconda3\envs\pythondata\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.7.1)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in c:\users\admin\anaconda3\envs\pythondata\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.5.13)
# Requirement already satisfied: jupyterlab-pygments in c:\users\admin\anaconda3\envs\pythondata\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.1.2)
# Requirement already satisfied: soupsieve>1.2 in c:\users\admin\anaconda3\envs\pythondata\lib\site-packages (from beautifulsoup4->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (2.3.1)
# Requirement already satisfied: webencodings in c:\users\admin\anaconda3\envs\pythondata\lib\site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (0.5.1)
# Requirement already satisfied: packaging in c:\users\admin\anaconda3\envs\pythondata\lib\site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\admin\anaconda3\envs\pythondata\lib\site-packages (from packaging->bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->gmaps) (3.0.4)
# Building wheels for collected packages: gmaps
#   Building wheel for gmaps (setup.py): started
#   Building wheel for gmaps (setup.py): finished with status 'done'
#   Created wheel for gmaps: filename=gmaps-0.9.0-py2.py3-none-any.whl size=2076111 sha256=4d1cb897168faf5719dbd54819fe5b8d269ba691a3e8c7e4954755e6eccdf394
#   Stored in directory: c:\users\admin\appdata\local\pip\cache\wheels\3d\1c\cb\c46f4199210e632b28d78d05a00bfdccbf6dfcd3f5b051d6bf
# Successfully built gmaps
# Installing collected packages: geojson, gmaps
# Successfully installed geojson-2.5.0 gmaps-0.9.0

# %%
# Dependencies and Setup
import pandas as pd
import gmaps
import requests

# Import API key

from config import g_key

# Configure gmaps API key
gmaps.configure(api_key=g_key)

# %%
# 1. Import the WeatherPy_database.csv file. 
city_data_df = pd.read_csv("Weather_Database/WeatherPy_database.csv")
city_data_df
# Out:
#      City_ID                City      Lat       Lng  Max Temp  Humidity  \
# 0          0       Joao Pinheiro -17.7425  -46.1725     64.20        52
# 1          1           Tuatapere -46.1333  167.6833     48.13        75
# 2          2             Mataura -46.1927  168.8643     46.47        89
# 3          3               Bluff -46.6000  168.3333     46.80        71
# 4          4         Derzhavinsk  51.1000   66.3167     73.78        52
# ..       ...                 ...      ...       ...       ...       ...
# 715      715  Puerto Del Rosario  28.5004  -13.8627     69.55        78
# 716      716              Festus  38.2206  -90.3960     74.75        87
# 717      717            Chunoyar  57.4467   97.3217     67.98        64
# 718      718              Marevo  57.3146   32.0804     51.15        92
# 719      719         Severomuysk  56.1481  113.4267     60.71        46
#
#      Cloudiness  Wind Speed Country Weather Description
# 0             0        7.11      BR           clear sky
# 1             6        4.07      NZ           clear sky
# 2            68        1.19      NZ       broken clouds
# 3            61        7.05      NZ       broken clouds
# 4           100       10.83      KZ     overcast clouds
# ..          ...         ...     ...                 ...
# 715         100       19.57      ES     overcast clouds
# 716           0        5.68      US           clear sky
# 717         100        3.83      RU     overcast clouds
# 718          80        4.14      RU       broken clouds
# 719          23        8.14      RU          few clouds
#
# [720 rows x 10 columns]

# %%
# 2. Prompt the user to enter minimum and maximum temperature criteria 

min_temp = float(input("What is the minimum temperature you would like for your trip? "))
max_temp = float(input("What is the maximum temperature you would like for your trip? "))
# Out:
# What is the minimum temperature you would like for your trip? 35
# What is the maximum temperature you would like for your trip? 80

# %%
# 3. Filter the city_data_df DataFrame using the input statements to create a new DataFrame using the loc method.

preferred_cities_df = city_data_df.loc[(city_data_df["Max Temp"] <= max_temp) & \
                                       (city_data_df["Max Temp"] >= min_temp)]
preferred_cities_df
# Out:
#      City_ID                City      Lat       Lng  Max Temp  Humidity  \
# 0          0       Joao Pinheiro -17.7425  -46.1725     64.20        52
# 1          1           Tuatapere -46.1333  167.6833     48.13        75
# 2          2             Mataura -46.1927  168.8643     46.47        89
# 3          3               Bluff -46.6000  168.3333     46.80        71
# 4          4         Derzhavinsk  51.1000   66.3167     73.78        52
# ..       ...                 ...      ...       ...       ...       ...
# 715      715  Puerto Del Rosario  28.5004  -13.8627     69.55        78
# 716      716              Festus  38.2206  -90.3960     74.75        87
# 717      717            Chunoyar  57.4467   97.3217     67.98        64
# 718      718              Marevo  57.3146   32.0804     51.15        92
# 719      719         Severomuysk  56.1481  113.4267     60.71        46
#
#      Cloudiness  Wind Speed Country Weather Description
# 0             0        7.11      BR           clear sky
# 1             6        4.07      NZ           clear sky
# 2            68        1.19      NZ       broken clouds
# 3            61        7.05      NZ       broken clouds
# 4           100       10.83      KZ     overcast clouds
# ..          ...         ...     ...                 ...
# 715         100       19.57      ES     overcast clouds
# 716           0        5.68      US           clear sky
# 717         100        3.83      RU     overcast clouds
# 718          80        4.14      RU       broken clouds
# 719          23        8.14      RU          few clouds
#
# [554 rows x 10 columns]

# %%
# 4a. Determine if there are any empty rows.
preferred_cities_df.count()
# Out:
# City_ID                554
# City                   554
# Lat                    554
# Lng                    554
# Max Temp               554
# Humidity               554
# Cloudiness             554
# Wind Speed             554
# Country                548
# Weather Description    554
# dtype: int64

# %%
# 4b. Drop any empty rows and create a new DataFrame that doesn’t have empty rows.
clean_df = preferred_cities_df.dropna()
clean_df
# Out:
#      City_ID                City      Lat       Lng  Max Temp  Humidity  \
# 0          0       Joao Pinheiro -17.7425  -46.1725     64.20        52
# 1          1           Tuatapere -46.1333  167.6833     48.13        75
# 2          2             Mataura -46.1927  168.8643     46.47        89
# 3          3               Bluff -46.6000  168.3333     46.80        71
# 4          4         Derzhavinsk  51.1000   66.3167     73.78        52
# ..       ...                 ...      ...       ...       ...       ...
# 715      715  Puerto Del Rosario  28.5004  -13.8627     69.55        78
# 716      716              Festus  38.2206  -90.3960     74.75        87
# 717      717            Chunoyar  57.4467   97.3217     67.98        64
# 718      718              Marevo  57.3146   32.0804     51.15        92
# 719      719         Severomuysk  56.1481  113.4267     60.71        46
#
#      Cloudiness  Wind Speed Country Weather Description
# 0             0        7.11      BR           clear sky
# 1             6        4.07      NZ           clear sky
# 2            68        1.19      NZ       broken clouds
# 3            61        7.05      NZ       broken clouds
# 4           100       10.83      KZ     overcast clouds
# ..          ...         ...     ...                 ...
# 715         100       19.57      ES     overcast clouds
# 716           0        5.68      US           clear sky
# 717         100        3.83      RU     overcast clouds
# 718          80        4.14      RU       broken clouds
# 719          23        8.14      RU          few clouds
#
# [548 rows x 10 columns]

# %%
# 5a. Create DataFrame called hotel_df to store hotel names along with city, country, max temp, and coordinates.
hotel_df = clean_df[["City", "Country", "Max Temp", "Weather Description", "Lat", "Lng"]].copy()

# 5b. Create a new column "Hotel Name"
hotel_df["Hotel Name"] = ""
hotel_df
# Out:
#                    City Country  Max Temp Weather Description      Lat  \
# 0         Joao Pinheiro      BR     64.20           clear sky -17.7425
# 1             Tuatapere      NZ     48.13           clear sky -46.1333
# 2               Mataura      NZ     46.47       broken clouds -46.1927
# 3                 Bluff      NZ     46.80       broken clouds -46.6000
# 4           Derzhavinsk      KZ     73.78     overcast clouds  51.1000
# ..                  ...     ...       ...                 ...      ...
# 715  Puerto Del Rosario      ES     69.55     overcast clouds  28.5004
# 716              Festus      US     74.75           clear sky  38.2206
# 717            Chunoyar      RU     67.98     overcast clouds  57.4467
# 718              Marevo      RU     51.15       broken clouds  57.3146
# 719         Severomuysk      RU     60.71          few clouds  56.1481
#
#           Lng Hotel Name
# 0    -46.1725
# 1    167.6833
# 2    168.8643
# 3    168.3333
# 4     66.3167
# ..        ...        ...
# 715  -13.8627
# 716  -90.3960
# 717   97.3217
# 718   32.0804
# 719  113.4267
#
# [548 rows x 7 columns]

# %%
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# 6a. Set parameters to search for hotels with 5000 meters.
params = {
    "radius": 5000,
    "type": "lodging",
    "key": g_key
}

# 6b. Iterate through the hotel DataFrame.
for index, row in hotel_df.iterrows():
    
    # 6c. Get latitude and longitude from DataFrame
    
    lat = row["Lat"]
    lng = row["Lng"]
    
    # Add the latitude and longitude to location key for the params dictionary.
    params["location"] = f"{lat},{lng}"
    
    # 6d. Set up the base URL for the Google Directions API to get JSON data.
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

    # 6e. Make request and retrieve the JSON data from the search. 
    hotels = requests.get(base_url, params=params).json()
    
# 6f. Get the first hotel from the results and store the name, if a hotel isn't found skip the city.  
try:
    hotel_df.loc[index, "Hotel Name"] = hotels["results"][0]["name"]
except (IndexError):
    print("Hotel not found... skipping")

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Hotel not found... skipping
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
hotel_df
# Out:
#                    City Country  Max Temp Weather Description      Lat  \
# 0         Joao Pinheiro      BR     64.20           clear sky -17.7425
# 1             Tuatapere      NZ     48.13           clear sky -46.1333
# 2               Mataura      NZ     46.47       broken clouds -46.1927
# 3                 Bluff      NZ     46.80       broken clouds -46.6000
# 4           Derzhavinsk      KZ     73.78     overcast clouds  51.1000
# ..                  ...     ...       ...                 ...      ...
# 715  Puerto Del Rosario      ES     69.55     overcast clouds  28.5004
# 716              Festus      US     74.75           clear sky  38.2206
# 717            Chunoyar      RU     67.98     overcast clouds  57.4467
# 718              Marevo      RU     51.15       broken clouds  57.3146
# 719         Severomuysk      RU     60.71          few clouds  56.1481
#
#           Lng Hotel Name
# 0    -46.1725
# 1    167.6833
# 2    168.8643
# 3    168.3333
# 4     66.3167
# ..        ...        ...
# 715  -13.8627
# 716  -90.3960
# 717   97.3217
# 718   32.0804
# 719  113.4267
#
# [548 rows x 7 columns]

# %%
# 7. Drop the rows where there is no Hotel Name.
clean_hotel_df = hotel_df.loc[(hotel_df["Hotel Name"]!="")]
clean_hotel_df
# Out:
# Empty DataFrame
# Columns: [City, Country, Max Temp, Weather Description, Lat, Lng, Hotel Name]
# Index: []

# %%
# 8a. Create the output File (CSV)

# 8b. Export the City_Data into a csv
clean_hotel_df.to_csv(output_data_file, index_label="City_ID")

# %%
# 9. Using the template add city name, the country code, the weather description and maximum temperature for the city.
info_box_template = """

"""

# 10a. Get the data from each row and add it to the formatting template and store the data in a list.
hotel_info = [info_box_template.format(**row) for index, row in clean_hotel_df.iterrows()]

# 10b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = clean_hotel_df[["Lat", "Lng"]]

# %%
# 11a. Add a marker layer for each city to the map. 

# 11b. Display the figure
